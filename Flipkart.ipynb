# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Flipkart_Mobiles.csv')
df.sample(5)
# Out:
#         Brand                         Model          Color Memory Storage  \
# 2111  SAMSUNG                Galaxy Note 4     Bronze Gold   3 GB   32 GB
# 997     Nokia                           2.1  Grey / Silver   1 GB    8 GB
# 187      OPPO  Rohit Sharma Limited Edition          Black   4 GB   64 GB
# 556    realme              Narzo 30 Pro 5G     Sword Black   6 GB   64 GB
# 2279   Lenovo                            B           White   1 GB    8 GB
#
#       Rating  Selling Price  Original Price
# 2111     4.1          51000           51000
# 997      4.0           7739            7739
# 187      4.4          22990           22990
# 556      4.3          16999           18999
# 2279     3.8           6799            6799

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Color', 'Memory', 'Storage', 'Rating',
#        'Selling Price', 'Original Price'],
#       dtype='object')

# %%
df['Brand'].unique()
# Out:
# array(['OPPO', 'HTC', 'IQOO', 'Google Pixel', 'LG', 'ASUS', 'realme',
#        'GIONEE', 'Nokia', 'Apple', 'SAMSUNG', 'Lenovo', 'Motorola',
#        'POCO', 'vivo', 'Xiaomi', 'Infinix'], dtype=object)

# %%
df['Mobile']=df['Brand'].str.cat(df['Model'],sep=' ')
df.sample(5)
# Out:
#         Brand                Model         Color Memory Storage  Rating  \
# 483      ASUS        Zenfone Zoom          Black   4 GB  128 GB     3.6
# 2618   Xiaomi        Redmi Note 8   Neptune Blue   4 GB   64 GB     4.4
# 38       OPPO                 A11K     Deep Blue   2 GB   32 GB     4.2
# 1777  SAMSUNG                M02s            Red   3 GB   32 GB     4.2
# 2054  SAMSUNG  Galaxy Note10 Lite      Aura Glow   6 GB  128 GB     4.3
#
#       Selling Price  Original Price                       Mobile
# 483           37999           37999           ASUS Zenfone Zoom
# 2618          12999           12999         Xiaomi Redmi Note 8
# 38             8990           10990                    OPPO A11K
# 1777           8999            8999                SAMSUNG M02s
# 2054          37999           43000  SAMSUNG Galaxy Note10 Lite

# %%
df.drop(columns=['Color','Model','Rating'],inplace=True)
df
# Out:
#         Brand Memory Storage  Selling Price  Original Price          Mobile
# 0        OPPO   4 GB   64 GB          11990           15990        OPPO A53
# 1        OPPO   4 GB   64 GB          11990           15990        OPPO A53
# 2        OPPO   6 GB  128 GB          13990           17990        OPPO A53
# 3        OPPO   6 GB  128 GB          13990           17990        OPPO A53
# 4        OPPO   4 GB   64 GB          11990           15990        OPPO A53
# ...       ...    ...     ...            ...             ...             ...
# 3109  SAMSUNG   6 GB  128 GB          25990           25990  SAMSUNG M52 5G
# 3110  SAMSUNG   6 GB  128 GB          25489           28449  SAMSUNG M52 5G
# 3111  SAMSUNG   8 GB  128 GB          27239           31489  SAMSUNG M52 5G
# 3112  SAMSUNG   8 GB  128 GB          22989           22989  SAMSUNG M52 5G
# 3113  SAMSUNG   8 GB  128 GB          20350           22595  SAMSUNG M52 5G
#
# [3114 rows x 6 columns]

# %%
df=df.sort_values(by='Mobile')
df
# Out:
#      Brand Memory Storage  Selling Price  Original Price       Mobile
# 426   ASUS   8 GB  256 GB          43999           43999     ASUS 6Z
# 447   ASUS   8 GB  256 GB          43999           43999     ASUS 6Z
# 465   ASUS   6 GB  128 GB          38999           38999     ASUS 6Z
# 390   ASUS   6 GB   64 GB          35999           35999     ASUS 6Z
# 462   ASUS   8 GB  256 GB          43999           43999     ASUS 6Z
# ...    ...    ...     ...            ...             ...          ...
# 2802  vivo   4 GB   64 GB          15990           15990  vivo Z1 Pro
# 2801  vivo   6 GB   64 GB          17990           17990  vivo Z1 Pro
# 2800  vivo   4 GB   64 GB          15990           15990  vivo Z1 Pro
# 2797  vivo   6 GB   64 GB          19990           19990     vivo Z1x
# 2796  vivo   6 GB   64 GB          19990           19990     vivo Z1x
#
# [3114 rows x 6 columns]

# %%
df.describe().T
# Out:
#                  count          mean           std     min       25%      50%  \
# Selling Price   3114.0  26436.625562  30066.892622  1000.0   9990.00  15000.0
# Original Price  3114.0  28333.473025  31525.599889  1000.0  10030.25  16889.5
#
#                     75%       max
# Selling Price   28999.0  179900.0
# Original Price  31500.0  189999.0

# %%
df.isnull().sum()
# Out:
# Brand              0
# Memory            43
# Storage           39
# Selling Price      0
# Original Price     0
# Mobile             0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Brand             0
# Memory            0
# Storage           0
# Selling Price     0
# Original Price    0
# Mobile            0
# dtype: int64

# %%
df.shape
# Out:
# (3032, 6)

# %%
df['Mobile'].unique()
# Out:
# array(['ASUS 6Z ', 'ASUS ROG ', 'ASUS ROG 5s', 'ASUS ROG 5s Pro',
#        'ASUS ROG Phone 3 ', 'ASUS ROG Phone 5 ', 'ASUS ROG Phone 5 Pro ',
#        'ASUS ROG Phone 5 Ultimate ', 'ASUS ROG Phone II ',
#        'ASUS ZenFone 5Z ', 'ASUS ZenFone Lite L1 ',
#        'ASUS ZenFone Max M1 ', 'ASUS ZenFone Max M2 ',
#        'ASUS ZenFone Max Pro M2 ', 'ASUS Zenfone 2 Laser ZE500KL ',
#        'ASUS Zenfone 4 Selfie ', 'ASUS Zenfone C ', 'ASUS Zenfone GO ',
#        'ASUS Zenfone Go ', 'ASUS Zenfone Go 2nd Gen',
#        'ASUS Zenfone Go 3rd Gen', 'ASUS Zenfone Go 4.5 ',
#        'ASUS Zenfone Go 4.5 LTE ', 'ASUS Zenfone Go 5.0 ',
#        'ASUS Zenfone Go 5.0 LTE ', 'ASUS Zenfone Go 5.0 LTE 2nd Gen ',
#        'ASUS Zenfone Go 5.5 ', 'ASUS Zenfone Live ', 'ASUS Zenfone Max ',
#        'ASUS Zenfone Max Pro M1 ', 'ASUS Zenfone Max ZC550KL ',
#        'ASUS Zenfone Selfie ', 'ASUS Zenfone Zoom ', 'Apple iPhone 11 ',
#        'Apple iPhone 11 Pro ', 'Apple iPhone 11 Pro Max ',
# ...

# %%
len(df['Mobile'].unique())
# Out:
# 919

# %%
df['Brand'].nunique()
# Out:
# 17

# %%
df['Brand'].unique()
# Out:
# array(['ASUS', 'Apple', 'GIONEE', 'Google Pixel', 'HTC', 'IQOO',
#        'Infinix', 'LG', 'Lenovo', 'Motorola', 'Nokia', 'OPPO', 'POCO',
#        'SAMSUNG', 'Xiaomi', 'realme', 'vivo'], dtype=object)

# %% [markdown]
# # EXPLORE PRICE

# %%
df['Original Price'].unique()
# Out:
# array([ 43999,  38999,  35999,  83999,  55999,  63999,  85999,  65999,
#         57999,  75999,  40999,  62999,  32999,  36299,   7199,   9599,
#         14999,  12999,  17999,  15999,  19999,   7999,  10999,   6299,
#          8499,   7499,   5699,   7300,   4649,   5299,   6999,   8999,
#          4890,   4880,   4990,   4499,   4999,   5840,   5990,   7668,
#          6990,   7699,  15599,  13199,  14499,   8690,   7990,  11999,
#          6749,  12490,   9999,  13999,  14500,  37999,  64900,  49900,
#         54900, 121300, 106600, 140300, 150800, 131900, 117100,  65900,
#         70900,  80900,  94900,  79900,  84900,  74900,  59900, 139900,
#        119900, 109900,  89900,  99900,  69900, 149900, 169900, 129900,
#        179900, 159900,  52000,  71500,  62500,  30780,  36499,  62000,
#         44999,  36990,  49999,  39999,  48999,  80500,  29900,  31999,
#         72000,  41999,  70000,  59999,  34900,  74400,  31500,  37900,
# ...

# %%
df['Selling Price'].unique()
# Out:
# array([ 43999,  38999,  35999,  26499,  49999,  57999,  79999,  46999,
#         69999,  40999,  62999,  32999,  36299,   7199,   9599,  14999,
#         12999,  17999,  15999,  19999,   7999,  10999,   6299,   8499,
#          7499,   5699,   7300,   4649,   5299,   6999,   8999,   4890,
#          4880,   4990,   4499,   4999,   5840,   5990,   7668,   6990,
#          7699,  15599,  13199,  14499,   8690,   7990,  11999,   6749,
#         12490,   9999,  13999,  14500,  37999,  64900,  49900,  54900,
#        121300, 140300,  99900, 150800, 131900, 117100,  63999,  68999,
#         78999,  61999,  71999,  56999, 139900, 119900, 109900, 104900,
#         89900,  79900,  69900, 149900, 169900, 129900, 179900, 159900,
#         94900,  52000,  71500,  62500,  30780,  36499,  62000,  44999,
#         36990,  39999,  48999,  80500,  29900,  31999,  72000,  55999,
#         41999,  25299,  70000,  59999,  34900,  74400,  24999,  36999,
# ...

# %%
df['Discount']=df['Original Price']-df['Selling Price']

# %%
df.reset_index(drop='index',inplace=True)

# %%
df
# Out:
#      Brand Memory Storage  Selling Price  Original Price             Mobile  \
# 0     ASUS   8 GB  256 GB          43999           43999           ASUS 6Z
# 86    ASUS   2 GB   32 GB           7699            7699  ASUS Zenfone Max
# 85    ASUS   2 GB   16 GB           7499            7499  ASUS Zenfone Max
# 84    ASUS   2 GB   32 GB           6999            6999  ASUS Zenfone Max
# 83    ASUS   2 GB   16 GB           6990            6990  ASUS Zenfone Max
# ...    ...    ...     ...            ...             ...                ...
# 2944  vivo   8 GB  128 GB          38990           41990    vivo V23 Pro 5G
# 2943  vivo  12 GB  256 GB          43990           45990    vivo V23 Pro 5G
# 2942  vivo  12 GB  256 GB          43990           45990    vivo V23 Pro 5G
# 2940  vivo   8 GB  128 GB          29990           34990        vivo V23 5G
# 3031  vivo   6 GB   64 GB          19990           19990           vivo Z1x
#
#       Discount
# 0            0
# 86           0
# ...

# %%
df['Discount in %']=(df['Discount']/df['Original Price'])*100

# %%
df
# Out:
#      Brand Memory Storage  Selling Price  Original Price             Mobile  \
# 0     ASUS   8 GB  256 GB          43999           43999           ASUS 6Z
# 86    ASUS   2 GB   32 GB           7699            7699  ASUS Zenfone Max
# 85    ASUS   2 GB   16 GB           7499            7499  ASUS Zenfone Max
# 84    ASUS   2 GB   32 GB           6999            6999  ASUS Zenfone Max
# 83    ASUS   2 GB   16 GB           6990            6990  ASUS Zenfone Max
# ...    ...    ...     ...            ...             ...                ...
# 2944  vivo   8 GB  128 GB          38990           41990    vivo V23 Pro 5G
# 2943  vivo  12 GB  256 GB          43990           45990    vivo V23 Pro 5G
# 2942  vivo  12 GB  256 GB          43990           45990    vivo V23 Pro 5G
# 2940  vivo   8 GB  128 GB          29990           34990        vivo V23 5G
# 3031  vivo   6 GB   64 GB          19990           19990           vivo Z1x
#
#       Discount  Discount in %
# 0            0       0.000000
# ...

# %%
df['Mobile'].value_counts(ascending=False)
# Out:
# Apple iPhone 11                   36
# Apple iPhone XR                   27
# Apple iPhone 7                    21
# Apple iPhone 11 Pro               21
# Apple iPhone 7 Plus               20
#                                   ..
# SAMSUNG Galaxy Grand Prime 4g      1
# Nokia 225 4g ds                    1
# Nokia 220                          1
# LG G8s ThinQ                       1
# Lenovo S660                        1
# Name: Mobile, Length: 919, dtype: int64

# %%
df['Brand'].value_counts()
# Out:
# SAMSUNG         696
# Apple           369
# realme          294
# OPPO            260
# Nokia           209
# Xiaomi          197
# Infinix         151
# GIONEE          129
# Lenovo          121
# vivo            121
# ASUS            118
# Motorola        105
# LG               99
# POCO             74
# HTC              55
# Google Pixel     29
# IQOO              5
# Name: Brand, dtype: int64

# %%
df.describe().T
# Out:
#                  count          mean           std          min      25%  \
# Selling Price   3032.0  26186.404354  29291.841572  1000.000000   9996.0
# Original Price  3032.0  28113.184697  30843.861948  1000.000000  10490.0
# Discount        3032.0   1926.780343   5401.091290 -8000.000000      0.0
# Discount in %   3032.0      6.128774     11.192416  -160.320641      0.0
#
#                     50%           75%            max
# Selling Price   15299.5  28999.000000  179900.000000
# Original Price  16990.0  31489.250000  189999.000000
# Discount            0.0   2000.000000   75000.000000
# Discount in %       0.0      9.836388      70.610305

# %%
sns.displot(df, x= 'Selling Price',bins=[5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000,65000,70000,75000,80000], aspect=3.2,color='#a6e25a')

# %%
sns.countplot(x='Brand',data=df)
plt.xticks(rotation=90);

# %%
df1=df['Brand'].value_counts().reset_index()
df1.columns=['Brand',"Selling Price"]
df1
# Out:
#            Brand  Selling Price
# 0        SAMSUNG            696
# 1          Apple            369
# 2         realme            294
# 3           OPPO            260
# 4          Nokia            209
# 5         Xiaomi            197
# 6        Infinix            151
# 7         GIONEE            129
# 8         Lenovo            121
# 9           vivo            121
# 10          ASUS            118
# 11      Motorola            105
# 12            LG             99
# 13          POCO             74
# 14           HTC             55
# 15  Google Pixel             29
# 16          IQOO              5

# %%
sns.catplot(x="Brand",y="Discount",kind="bar",data=df,ci=None,height=5,aspect=2.5)
plt.xticks(rotation=75);

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x="Brand", y="Selling Price",data=df)
plt.xticks(rotation=75);

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x="Brand", y="Original Price", data=df)
plt.xticks(rotation=75);
